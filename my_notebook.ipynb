# %% [markdown]
# # Test Notebook

# %%
print("Hello world!")
# Out:
# Hello wolrd!

# %%
from greetings import greet_person

greet_person("Fred")
# Out:
# Hello Fred!

# %%
import pandas
df = pandas.read_csv("data/road_network_info.csv")
df
# Out:
#             ROAD  START_TRUE_DIST  RA_NO                NETWORK_TYPE  \
# 0           H001             0.00      7                  State Road
# 1           H001             0.03      7                  State Road
# 2           H001             0.08      7                  State Road
# 3           H001             0.10      7                  State Road
# 4           H001             0.24      7                  State Road
# ...          ...              ...    ...                         ...
# 11580       P316             0.00      7  Main Roads Controlled Path
# 11581       P316             0.86      7  Main Roads Controlled Path
# 11582       P316             1.49      7  Main Roads Controlled Path
# 11583  P316-R001             0.00      7  Main Roads Controlled Path
# 11584  P316-R002             0.00      7  Main Roads Controlled Path
#
#        START_SLK  END_SLK  END_TRUE_DIST     CWY
# 0           0.00     0.03           0.03    Left
# ...
